# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 1.12.0

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # 'input_shape' is only required here so that '.summary' works.
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape = (NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1,activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer = 'adam',
                      loss = 'binary_crossentropy',
                      metrics = ['accuracy','binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                     train_labels,
                                     epochs = 20,
                                     batch_size = 512,
                                     validation_data = (test_data, test_labels),
                                     verbose = 2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 6s - loss: 0.4811 - acc: 0.8112 - binary_crossentropy: 0.4811 - val_loss: 0.3263 - val_acc: 0.8793 - val_binary_crossentropy: 0.3263
# Epoch 2/20
#  - 5s - loss: 0.2404 - acc: 0.9140 - binary_crossentropy: 0.2404 - val_loss: 0.2834 - val_acc: 0.8871 - val_binary_crossentropy: 0.2834
# Epoch 3/20
#  - 5s - loss: 0.1764 - acc: 0.9387 - binary_crossentropy: 0.1764 - val_loss: 0.2917 - val_acc: 0.8844 - val_binary_crossentropy: 0.2917
# Epoch 4/20
#  - 5s - loss: 0.1410 - acc: 0.9522 - binary_crossentropy: 0.1410 - val_loss: 0.3197 - val_acc: 0.8783 - val_binary_crossentropy: 0.3197
# Epoch 5/20
#  - 5s - loss: 0.1170 - acc: 0.9614 - binary_crossentropy: 0.1170 - val_loss: 0.3466 - val_acc: 0.8741 - val_binary_crossentropy: 0.3466
# Epoch 6/20
#  - 5s - loss: 0.0959 - acc: 0.9708 - binary_crossentropy: 0.0959 - val_loss: 0.3794 - val_acc: 0.8693 - val_binary_crossentropy: 0.3794
# Epoch 7/20
#  - 5s - loss: 0.0778 - acc: 0.9777 - binary_crossentropy: 0.0778 - val_loss: 0.4298 - val_acc: 0.8619 - val_binary_crossentropy: 0.4298
# Epoch 8/20
#  - 5s - loss: 0.0625 - acc: 0.9829 - binary_crossentropy: 0.0625 - val_loss: 0.4602 - val_acc: 0.8623 - val_binary_crossentropy: 0.4602
# Epoch 9/20
#  - 5s - loss: 0.0486 - acc: 0.9894 - binary_crossentropy: 0.0486 - val_loss: 0.5028 - val_acc: 0.8592 - val_binary_crossentropy: 0.5028
# Epoch 10/20
#  - 5s - loss: 0.0371 - acc: 0.9930 - binary_crossentropy: 0.0371 - val_loss: 0.5492 - val_acc: 0.8568 - val_binary_crossentropy: 0.5492
# Epoch 11/20
#  - 5s - loss: 0.0283 - acc: 0.9957 - binary_crossentropy: 0.0283 - val_loss: 0.5889 - val_acc: 0.8569 - val_binary_crossentropy: 0.5889
# Epoch 12/20
#  - 5s - loss: 0.0213 - acc: 0.9972 - binary_crossentropy: 0.0213 - val_loss: 0.6320 - val_acc: 0.8555 - val_binary_crossentropy: 0.6320
# Epoch 13/20
#  - 5s - loss: 0.0156 - acc: 0.9981 - binary_crossentropy: 0.0156 - val_loss: 0.6716 - val_acc: 0.8539 - val_binary_crossentropy: 0.6716
# Epoch 14/20
#  - 5s - loss: 0.0115 - acc: 0.9994 - binary_crossentropy: 0.0115 - val_loss: 0.7076 - val_acc: 0.8532 - val_binary_crossentropy: 0.7076
# Epoch 15/20
#  - 5s - loss: 0.0086 - acc: 0.9998 - binary_crossentropy: 0.0086 - val_loss: 0.7392 - val_acc: 0.8532 - val_binary_crossentropy: 0.7392
# Epoch 16/20
#  - 5s - loss: 0.0069 - acc: 0.9998 - binary_crossentropy: 0.0069 - val_loss: 0.7667 - val_acc: 0.8530 - val_binary_crossentropy: 0.7667
# Epoch 17/20
#  - 5s - loss: 0.0055 - acc: 0.9999 - binary_crossentropy: 0.0055 - val_loss: 0.7911 - val_acc: 0.8538 - val_binary_crossentropy: 0.7911
# Epoch 18/20
#  - 5s - loss: 0.0045 - acc: 0.9999 - binary_crossentropy: 0.0045 - val_loss: 0.8163 - val_acc: 0.8514 - val_binary_crossentropy: 0.8163
# Epoch 19/20
#  - 5s - loss: 0.0038 - acc: 0.9999 - binary_crossentropy: 0.0038 - val_loss: 0.8350 - val_acc: 0.8533 - val_binary_crossentropy: 0.8350
# Epoch 20/20
#  - 5s - loss: 0.0032 - acc: 1.0000 - binary_crossentropy: 0.0032 - val_loss: 0.8560 - val_acc: 0.8518 - val_binary_crossentropy: 0.8560

# %%
#create smaller model
smaller_model = keras.Sequential([
    keras.layers.Dense(4,activation=tf.nn.relu,input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4,activation=tf.nn.relu),
    keras.layers.Dense(1,activation=tf.nn.sigmoid)
    
])

smaller_model.compile(optimizer = 'adam',
                     loss = 'binary_crossentropy',
                     metrics = ['accuracy','binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 4)                 40004
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 6s - loss: 0.5879 - acc: 0.7620 - binary_crossentropy: 0.5879 - val_loss: 0.4761 - val_acc: 0.8572 - val_binary_crossentropy: 0.4761
# Epoch 2/20
#  - 5s - loss: 0.3818 - acc: 0.8941 - binary_crossentropy: 0.3818 - val_loss: 0.3603 - val_acc: 0.8802 - val_binary_crossentropy: 0.3603
# Epoch 3/20
#  - 5s - loss: 0.2837 - acc: 0.9157 - binary_crossentropy: 0.2837 - val_loss: 0.3113 - val_acc: 0.8867 - val_binary_crossentropy: 0.3113
# Epoch 4/20
#  - 5s - loss: 0.2313 - acc: 0.9291 - binary_crossentropy: 0.2313 - val_loss: 0.2927 - val_acc: 0.8870 - val_binary_crossentropy: 0.2927
# Epoch 5/20
#  - 5s - loss: 0.1984 - acc: 0.9385 - binary_crossentropy: 0.1984 - val_loss: 0.2878 - val_acc: 0.8856 - val_binary_crossentropy: 0.2878
# Epoch 6/20
#  - 5s - loss: 0.1745 - acc: 0.9447 - binary_crossentropy: 0.1745 - val_loss: 0.2855 - val_acc: 0.8863 - val_binary_crossentropy: 0.2855
# Epoch 7/20
#  - 4s - loss: 0.1558 - acc: 0.9526 - binary_crossentropy: 0.1558 - val_loss: 0.2898 - val_acc: 0.8844 - val_binary_crossentropy: 0.2898
# Epoch 8/20
#  - 5s - loss: 0.1410 - acc: 0.9571 - binary_crossentropy: 0.1410 - val_loss: 0.2976 - val_acc: 0.8816 - val_binary_crossentropy: 0.2976
# Epoch 9/20
#  - 5s - loss: 0.1289 - acc: 0.9604 - binary_crossentropy: 0.1289 - val_loss: 0.3071 - val_acc: 0.8790 - val_binary_crossentropy: 0.3071
# Epoch 10/20
#  - 5s - loss: 0.1176 - acc: 0.9657 - binary_crossentropy: 0.1176 - val_loss: 0.3186 - val_acc: 0.8764 - val_binary_crossentropy: 0.3186
# Epoch 11/20
#  - 5s - loss: 0.1081 - acc: 0.9692 - binary_crossentropy: 0.1081 - val_loss: 0.3285 - val_acc: 0.8754 - val_binary_crossentropy: 0.3285
# Epoch 12/20
#  - 5s - loss: 0.0992 - acc: 0.9724 - binary_crossentropy: 0.0992 - val_loss: 0.3443 - val_acc: 0.8722 - val_binary_crossentropy: 0.3443
# Epoch 13/20
#  - 5s - loss: 0.0913 - acc: 0.9757 - binary_crossentropy: 0.0913 - val_loss: 0.3542 - val_acc: 0.8715 - val_binary_crossentropy: 0.3542
# Epoch 14/20
#  - 5s - loss: 0.0845 - acc: 0.9784 - binary_crossentropy: 0.0845 - val_loss: 0.3692 - val_acc: 0.8692 - val_binary_crossentropy: 0.3692
# Epoch 15/20
#  - 5s - loss: 0.0779 - acc: 0.9811 - binary_crossentropy: 0.0779 - val_loss: 0.3826 - val_acc: 0.8686 - val_binary_crossentropy: 0.3826
# Epoch 16/20
#  - 5s - loss: 0.0719 - acc: 0.9835 - binary_crossentropy: 0.0719 - val_loss: 0.3975 - val_acc: 0.8679 - val_binary_crossentropy: 0.3975
# Epoch 17/20
#  - 5s - loss: 0.0665 - acc: 0.9854 - binary_crossentropy: 0.0665 - val_loss: 0.4144 - val_acc: 0.8654 - val_binary_crossentropy: 0.4144
# Epoch 18/20
#  - 5s - loss: 0.0613 - acc: 0.9880 - binary_crossentropy: 0.0613 - val_loss: 0.4351 - val_acc: 0.8643 - val_binary_crossentropy: 0.4351
# Epoch 19/20
#  - 5s - loss: 0.0566 - acc: 0.9899 - binary_crossentropy: 0.0566 - val_loss: 0.4455 - val_acc: 0.8630 - val_binary_crossentropy: 0.4455
# Epoch 20/20
#  - 5s - loss: 0.0522 - acc: 0.9910 - binary_crossentropy: 0.0522 - val_loss: 0.4616 - val_acc: 0.8614 - val_binary_crossentropy: 0.4616

# %%
#create a bigger model
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 512)               5120512
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 10s - loss: 0.3492 - acc: 0.8529 - binary_crossentropy: 0.3492 - val_loss: 0.2981 - val_acc: 0.8787 - val_binary_crossentropy: 0.2981
# Epoch 2/20
#  - 9s - loss: 0.1383 - acc: 0.9494 - binary_crossentropy: 0.1383 - val_loss: 0.3504 - val_acc: 0.8644 - val_binary_crossentropy: 0.3504
# Epoch 3/20
#  - 9s - loss: 0.0464 - acc: 0.9866 - binary_crossentropy: 0.0464 - val_loss: 0.4243 - val_acc: 0.8684 - val_binary_crossentropy: 0.4243
# Epoch 4/20
#  - 9s - loss: 0.0072 - acc: 0.9994 - binary_crossentropy: 0.0072 - val_loss: 0.5932 - val_acc: 0.8670 - val_binary_crossentropy: 0.5932
# Epoch 5/20
#  - 9s - loss: 7.5963e-04 - acc: 1.0000 - binary_crossentropy: 7.5963e-04 - val_loss: 0.6824 - val_acc: 0.8690 - val_binary_crossentropy: 0.6824
# Epoch 6/20
#  - 9s - loss: 2.3677e-04 - acc: 1.0000 - binary_crossentropy: 2.3677e-04 - val_loss: 0.7191 - val_acc: 0.8696 - val_binary_crossentropy: 0.7191
# Epoch 7/20
#  - 9s - loss: 1.4238e-04 - acc: 1.0000 - binary_crossentropy: 1.4238e-04 - val_loss: 0.7457 - val_acc: 0.8698 - val_binary_crossentropy: 0.7457
# Epoch 8/20
#  - 9s - loss: 1.0054e-04 - acc: 1.0000 - binary_crossentropy: 1.0054e-04 - val_loss: 0.7662 - val_acc: 0.8703 - val_binary_crossentropy: 0.7662
# Epoch 9/20
#  - 9s - loss: 7.5823e-05 - acc: 1.0000 - binary_crossentropy: 7.5823e-05 - val_loss: 0.7835 - val_acc: 0.8706 - val_binary_crossentropy: 0.7835
# Epoch 10/20
#  - 9s - loss: 5.9482e-05 - acc: 1.0000 - binary_crossentropy: 5.9482e-05 - val_loss: 0.7972 - val_acc: 0.8706 - val_binary_crossentropy: 0.7972
# Epoch 11/20
#  - 9s - loss: 4.7928e-05 - acc: 1.0000 - binary_crossentropy: 4.7928e-05 - val_loss: 0.8107 - val_acc: 0.8705 - val_binary_crossentropy: 0.8107
# Epoch 12/20
#  - 9s - loss: 3.9380e-05 - acc: 1.0000 - binary_crossentropy: 3.9380e-05 - val_loss: 0.8221 - val_acc: 0.8705 - val_binary_crossentropy: 0.8221
# Epoch 13/20
#  - 9s - loss: 3.2908e-05 - acc: 1.0000 - binary_crossentropy: 3.2908e-05 - val_loss: 0.8318 - val_acc: 0.8705 - val_binary_crossentropy: 0.8318
# Epoch 14/20
#  - 9s - loss: 2.7908e-05 - acc: 1.0000 - binary_crossentropy: 2.7908e-05 - val_loss: 0.8418 - val_acc: 0.8706 - val_binary_crossentropy: 0.8418
# Epoch 15/20
#  - 9s - loss: 2.3884e-05 - acc: 1.0000 - binary_crossentropy: 2.3884e-05 - val_loss: 0.8509 - val_acc: 0.8705 - val_binary_crossentropy: 0.8509
# Epoch 16/20
#  - 9s - loss: 2.0649e-05 - acc: 1.0000 - binary_crossentropy: 2.0649e-05 - val_loss: 0.8585 - val_acc: 0.8705 - val_binary_crossentropy: 0.8585
# Epoch 17/20
#  - 9s - loss: 1.7963e-05 - acc: 1.0000 - binary_crossentropy: 1.7963e-05 - val_loss: 0.8677 - val_acc: 0.8704 - val_binary_crossentropy: 0.8677
# Epoch 18/20
#  - 9s - loss: 1.5772e-05 - acc: 1.0000 - binary_crossentropy: 1.5772e-05 - val_loss: 0.8743 - val_acc: 0.8703 - val_binary_crossentropy: 0.8743
# Epoch 19/20
#  - 9s - loss: 1.3918e-05 - acc: 1.0000 - binary_crossentropy: 1.3918e-05 - val_loss: 0.8811 - val_acc: 0.8703 - val_binary_crossentropy: 0.8811
# Epoch 20/20
#  - 9s - loss: 1.2374e-05 - acc: 1.0000 - binary_crossentropy: 1.2374e-05 - val_loss: 0.8885 - val_acc: 0.8704 - val_binary_crossentropy: 0.8885

# %%
# Plot the training and validation loss
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
#Strategies to combat over fitting

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 6s - loss: 0.5456 - acc: 0.7873 - binary_crossentropy: 0.5067 - val_loss: 0.3951 - val_acc: 0.8748 - val_binary_crossentropy: 0.3552
# Epoch 2/20
#  - 5s - loss: 0.3144 - acc: 0.9081 - binary_crossentropy: 0.2697 - val_loss: 0.3358 - val_acc: 0.8875 - val_binary_crossentropy: 0.2877
# Epoch 3/20
#  - 5s - loss: 0.2592 - acc: 0.9268 - binary_crossentropy: 0.2087 - val_loss: 0.3351 - val_acc: 0.8868 - val_binary_crossentropy: 0.2829
# Epoch 4/20
#  - 5s - loss: 0.2330 - acc: 0.9389 - binary_crossentropy: 0.1794 - val_loss: 0.3448 - val_acc: 0.8839 - val_binary_crossentropy: 0.2904
# Epoch 5/20
#  - 5s - loss: 0.2187 - acc: 0.9444 - binary_crossentropy: 0.1629 - val_loss: 0.3573 - val_acc: 0.8806 - val_binary_crossentropy: 0.3007
# Epoch 6/20
#  - 5s - loss: 0.2052 - acc: 0.9507 - binary_crossentropy: 0.1480 - val_loss: 0.3698 - val_acc: 0.8774 - val_binary_crossentropy: 0.3123
# Epoch 7/20
#  - 5s - loss: 0.1978 - acc: 0.9542 - binary_crossentropy: 0.1393 - val_loss: 0.3847 - val_acc: 0.8733 - val_binary_crossentropy: 0.3256
# Epoch 8/20
#  - 5s - loss: 0.1887 - acc: 0.9578 - binary_crossentropy: 0.1290 - val_loss: 0.3933 - val_acc: 0.8735 - val_binary_crossentropy: 0.3335
# Epoch 9/20
#  - 5s - loss: 0.1828 - acc: 0.9591 - binary_crossentropy: 0.1225 - val_loss: 0.4095 - val_acc: 0.8710 - val_binary_crossentropy: 0.3487
# Epoch 10/20
#  - 5s - loss: 0.1810 - acc: 0.9610 - binary_crossentropy: 0.1195 - val_loss: 0.4274 - val_acc: 0.8663 - val_binary_crossentropy: 0.3655
# Epoch 11/20
#  - 5s - loss: 0.1755 - acc: 0.9630 - binary_crossentropy: 0.1131 - val_loss: 0.4335 - val_acc: 0.8670 - val_binary_crossentropy: 0.3707
# Epoch 12/20
#  - 5s - loss: 0.1719 - acc: 0.9647 - binary_crossentropy: 0.1089 - val_loss: 0.4507 - val_acc: 0.8625 - val_binary_crossentropy: 0.3873
# Epoch 13/20
#  - 5s - loss: 0.1712 - acc: 0.9646 - binary_crossentropy: 0.1070 - val_loss: 0.4587 - val_acc: 0.8640 - val_binary_crossentropy: 0.3943
# Epoch 14/20
#  - 5s - loss: 0.1626 - acc: 0.9690 - binary_crossentropy: 0.0982 - val_loss: 0.4653 - val_acc: 0.8615 - val_binary_crossentropy: 0.4012
# Epoch 15/20
#  - 5s - loss: 0.1572 - acc: 0.9709 - binary_crossentropy: 0.0931 - val_loss: 0.4797 - val_acc: 0.8623 - val_binary_crossentropy: 0.4155
# Epoch 16/20
#  - 5s - loss: 0.1550 - acc: 0.9718 - binary_crossentropy: 0.0905 - val_loss: 0.4929 - val_acc: 0.8597 - val_binary_crossentropy: 0.4282
# Epoch 17/20
#  - 5s - loss: 0.1535 - acc: 0.9714 - binary_crossentropy: 0.0887 - val_loss: 0.5044 - val_acc: 0.8574 - val_binary_crossentropy: 0.4392
# Epoch 18/20
#  - 5s - loss: 0.1522 - acc: 0.9722 - binary_crossentropy: 0.0866 - val_loss: 0.5232 - val_acc: 0.8562 - val_binary_crossentropy: 0.4572
# Epoch 19/20
#  - 5s - loss: 0.1506 - acc: 0.9720 - binary_crossentropy: 0.0844 - val_loss: 0.5311 - val_acc: 0.8588 - val_binary_crossentropy: 0.4644
# Epoch 20/20
#  - 5s - loss: 0.1493 - acc: 0.9728 - binary_crossentropy: 0.0822 - val_loss: 0.5434 - val_acc: 0.8544 - val_binary_crossentropy: 0.4760

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 6s - loss: 0.6361 - acc: 0.6268 - binary_crossentropy: 0.6361 - val_loss: 0.5005 - val_acc: 0.8474 - val_binary_crossentropy: 0.5005
# Epoch 2/20
#  - 5s - loss: 0.4663 - acc: 0.8061 - binary_crossentropy: 0.4663 - val_loss: 0.3529 - val_acc: 0.8788 - val_binary_crossentropy: 0.3529
# Epoch 3/20
#  - 5s - loss: 0.3669 - acc: 0.8622 - binary_crossentropy: 0.3669 - val_loss: 0.3017 - val_acc: 0.8863 - val_binary_crossentropy: 0.3017
# Epoch 4/20
#  - 5s - loss: 0.3050 - acc: 0.8914 - binary_crossentropy: 0.3050 - val_loss: 0.2830 - val_acc: 0.8866 - val_binary_crossentropy: 0.2830
# Epoch 5/20
#  - 5s - loss: 0.2618 - acc: 0.9108 - binary_crossentropy: 0.2618 - val_loss: 0.2833 - val_acc: 0.8879 - val_binary_crossentropy: 0.2833
# Epoch 6/20
#  - 5s - loss: 0.2278 - acc: 0.9236 - binary_crossentropy: 0.2278 - val_loss: 0.2879 - val_acc: 0.8842 - val_binary_crossentropy: 0.2879
# Epoch 7/20
#  - 5s - loss: 0.2028 - acc: 0.9339 - binary_crossentropy: 0.2028 - val_loss: 0.3067 - val_acc: 0.8811 - val_binary_crossentropy: 0.3067
# Epoch 8/20
#  - 5s - loss: 0.1806 - acc: 0.9418 - binary_crossentropy: 0.1806 - val_loss: 0.3255 - val_acc: 0.8833 - val_binary_crossentropy: 0.3255
# Epoch 9/20
#  - 5s - loss: 0.1595 - acc: 0.9466 - binary_crossentropy: 0.1595 - val_loss: 0.3500 - val_acc: 0.8810 - val_binary_crossentropy: 0.3500
# Epoch 10/20
#  - 5s - loss: 0.1484 - acc: 0.9524 - binary_crossentropy: 0.1484 - val_loss: 0.3556 - val_acc: 0.8780 - val_binary_crossentropy: 0.3556
# Epoch 11/20
#  - 5s - loss: 0.1373 - acc: 0.9556 - binary_crossentropy: 0.1373 - val_loss: 0.3690 - val_acc: 0.8778 - val_binary_crossentropy: 0.3690
# Epoch 12/20
#  - 5s - loss: 0.1244 - acc: 0.9618 - binary_crossentropy: 0.1244 - val_loss: 0.4030 - val_acc: 0.8782 - val_binary_crossentropy: 0.4030
# Epoch 13/20
#  - 5s - loss: 0.1176 - acc: 0.9625 - binary_crossentropy: 0.1176 - val_loss: 0.4328 - val_acc: 0.8738 - val_binary_crossentropy: 0.4328
# Epoch 14/20
#  - 5s - loss: 0.1059 - acc: 0.9658 - binary_crossentropy: 0.1059 - val_loss: 0.4362 - val_acc: 0.8766 - val_binary_crossentropy: 0.4362
# Epoch 15/20
#  - 5s - loss: 0.0995 - acc: 0.9670 - binary_crossentropy: 0.0995 - val_loss: 0.4699 - val_acc: 0.8759 - val_binary_crossentropy: 0.4699
# Epoch 16/20
#  - 5s - loss: 0.0937 - acc: 0.9694 - binary_crossentropy: 0.0937 - val_loss: 0.4873 - val_acc: 0.8749 - val_binary_crossentropy: 0.4873
# Epoch 17/20
#  - 5s - loss: 0.0895 - acc: 0.9716 - binary_crossentropy: 0.0895 - val_loss: 0.4979 - val_acc: 0.8750 - val_binary_crossentropy: 0.4979
# Epoch 18/20
#  - 5s - loss: 0.0856 - acc: 0.9716 - binary_crossentropy: 0.0856 - val_loss: 0.5296 - val_acc: 0.8753 - val_binary_crossentropy: 0.5296
# Epoch 19/20
#  - 5s - loss: 0.0835 - acc: 0.9729 - binary_crossentropy: 0.0835 - val_loss: 0.5325 - val_acc: 0.8744 - val_binary_crossentropy: 0.5325
# Epoch 20/20
#  - 5s - loss: 0.0762 - acc: 0.9764 - binary_crossentropy: 0.0762 - val_loss: 0.5567 - val_acc: 0.8741 - val_binary_crossentropy: 0.5567

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
